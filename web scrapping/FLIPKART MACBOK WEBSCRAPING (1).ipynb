# %% [markdown]
# **Import the required Modules:**

# %%
import requests
import time
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# **See the structure of URL:**

# %%
#https://www.flipkart.com/search?q=macbook&sid=6bo%2Cb5g&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_3_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_3_na_na_na&as-pos=1&as-type=RECENT&suggestionId=macbook%7CLaptops&requestId=725f153c-36bb-478c-8f10-e54c60187a13&as-backfill=on&page=1
#https://www.flipkart.com/search?q=macbook&sid=6bo%2Cb5g&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_3_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_3_na_na_na&as-pos=1&as-type=RECENT&suggestionId=macbook%7CLaptops&requestId=725f153c-36bb-478c-8f10-e54c60187a13&as-backfill=on&page=2

# %%
base_url = 'https://www.flipkart.com/search?q=macbook&as=on&as-show=on&otracker=AS_Query_HistoryAutoSuggest_1_3_na_na_na&otracker1=AS_Query_HistoryAutoSuggest_1_3_na_na_na&as-pos=1&as-type=HISTORY&suggestionId=macbook&requestId=b3da5e2a-7578-4a9d-b8a6-0f2ebaeb0fb7&as-searchtext=MAC'

# %% [markdown]
# **Create List for store the Data**

# %%
pd_name = []
price =[]
ratings = []
warranty = []
ratingsno = []
reviewsno = []
features = []
for i in range(1,3):
  time.sleep(3)
  req = requests.get(base_url+str(i))
  soup = BeautifulSoup(req.text,'html')

  #product name
  pdt_name = soup.findAll('div',attrs={'class':'_4rR01T'})
  [pd_name.append(i.text) for i in pdt_name]

  #price
  p = soup.findAll('div',attrs={'class':'_30jeq3 _1_WHN1'})
  [price.append(i.text) for i in p]

  #ratings
  r = soup.findAll('div',attrs={'class':'gUuXy-'})
  [ratings.append(i.span.div.text) for i in r]

  #warranty
  wl = soup.findAll('ul',attrs={'class':'_1xgFaf'})
  w = [i.findAll('li')[-1] for i in wl]
  [warranty.append(i.text) for i in w]

  #number of ratings and reviews
  a = soup.findAll('span',attrs={'class':'_2_R_DZ'})
  for i in a:
    a = i.text.split('&')
    ratingsno.append(a[0].split(" ")[0])
    reviewsno.append(a[1].split(" ")[0])

  #features
  prop = soup.findAll('ul',attrs={'class':'_1xgFaf'})
  for i in prop:
    a = i.findAll('li')[0:-2]
    b =[i.text for i in a]
    features.append(','.join(b))

# %%
print('pd_name= ',len(pd_name))
print('price = ',len(price))
print('ratings = ',len(ratings))
print('warranty = ',len(warranty))
print('ratingsno =',len(ratingsno))
print('reviewsno = ',len(reviewsno))
print('features = ',len(features))
# Out:
# pd_name=  48
# price =  48
# ratings =  48
# warranty =  48
# ratingsno = 48
# reviewsno =  48
# features =  48

# %%
data = pd.DataFrame({'Product':pd_name,
                     'Price':price,
                     'Ratings':ratings,
                     'Warranty':warranty,
                     'No of Ratings':ratingsno,
                     'No of Reviews':reviewsno,
                     'Features':features})
data
# Out:
#                                               Product      Price Ratings  \
# 0   APPLE 2020 Macbook Air M1 - (8 GB/256 GB SSD/M...    ₹84,940     4.7
# 1   APPLE 2020 Macbook Air M1 - (8 GB/512 GB SSD/M...    ₹99,940     4.7
# 2   APPLE 2020 Macbook Air M1 - (8 GB/512 GB SSD/M...  ₹1,08,940     4.7
# 3   APPLE MacBook Air M1 - (16 GB/256 GB SSD/Mac O...  ₹1,05,940     4.7
# 4   APPLE MacBook Air M1 - (16 GB/512 GB SSD/Mac O...  ₹1,27,940     4.7
# 5   APPLE MacBook Air M1 - (16 GB/256 GB SSD/Mac O...  ₹1,05,940     4.7
# 6   APPLE MacBook Air M1 - (16 GB/512 GB SSD/Mac O...  ₹1,27,940     4.7
# 3   Apple M1 Processor,16 GB DDR4 RAM,Mac OS Opera...
# 4   Apple M1 Processor,16 GB DDR4 RAM,Mac OS Opera...
# 5   Apple M1 Processor,16 GB DDR4 RAM,Mac OS Opera...
# 6   Apple M1 Processor,16 GB DDR4 RAM,Mac OS Opera...
# 7   Apple M1 Processor,8 GB DDR4 RAM,Mac OS Operat...
# 8   Apple M1 Processor,16 GB DDR4 RAM,Mac OS Opera...
# 9   Intel Core i5 Processor (10th Gen),8 GB LPDDR4...
# 10  Apple M1 Processor,8 GB DDR4 RAM,Mac OS Operat...
# 11  Apple M1 Max Processor,32 GB Unified Memory RA...
# 12  Apple M1 Pro Processor,16 GB Unified Memory RA...
# 13  Apple M1 Pro Processor,16 GB Unified Memory RA...
# 14  Apple M1 Pro Processor,16 GB Unified Memory RA...
# 15  Apple M1 Pro Processor,16 GB Unified Memory RA...
# 16  Apple M1 Pro Processor,16 GB Unified Memory RA...
# 17  Apple M1 Pro Processor,16 GB Unified Memory RA...
# 18  Apple M1 Processor,8 GB DDR4 RAM,Mac OS Operat...
# 19  Apple M1 Processor,8 GB DDR4 RAM,Mac OS Operat...
# 20  Apple M1 Processor,8 GB DDR4 RAM,Mac OS Operat...
# 21  Apple M1 Processor,8 GB DDR4 RAM,Mac OS Operat...
# 22  Intel Core i5 Processor (10th Gen),16 GB LPDDR...
# 23  Intel Core i5 Processor (10th Gen),16 GB LPDDR...
# 24  Apple M1 Processor,8 GB DDR4 RAM,Mac OS Operat...
# 25  Apple M1 Processor,8 GB DDR4 RAM,Mac OS Operat...
# 26  Apple M1 Processor,8 GB DDR4 RAM,Mac OS Operat...
# 27  Apple M1 Processor,16 GB DDR4 RAM,Mac OS Opera...
# 28  Apple M1 Processor,16 GB DDR4 RAM,Mac OS Opera...
# 29  Apple M1 Processor,16 GB DDR4 RAM,Mac OS Opera...
# 30  Apple M1 Processor,16 GB DDR4 RAM,Mac OS Opera...
# 31  Apple M1 Processor,8 GB DDR4 RAM,Mac OS Operat...
# 32  Apple M1 Processor,16 GB DDR4 RAM,Mac OS Opera...
# 33  Intel Core i5 Processor (10th Gen),8 GB LPDDR4...
# 34  Apple M1 Processor,8 GB DDR4 RAM,Mac OS Operat...
# 35  Apple M1 Max Processor,32 GB Unified Memory RA...
# 36  Apple M1 Pro Processor,16 GB Unified Memory RA...
# 37  Apple M1 Pro Processor,16 GB Unified Memory RA...
# 38  Apple M1 Pro Processor,16 GB Unified Memory RA...
# 39  Apple M1 Pro Processor,16 GB Unified Memory RA...
# 40  Apple M1 Pro Processor,16 GB Unified Memory RA...
# 41  Apple M1 Pro Processor,16 GB Unified Memory RA...
# 42  Apple M1 Processor,8 GB DDR4 RAM,Mac OS Operat...
# 43  Apple M1 Processor,8 GB DDR4 RAM,Mac OS Operat...
# 44  Apple M1 Processor,8 GB DDR4 RAM,Mac OS Operat...
# 45  Apple M1 Processor,8 GB DDR4 RAM,Mac OS Operat...
# 46  Intel Core i5 Processor (10th Gen),16 GB LPDDR...
# 47  Intel Core i5 Processor (10th Gen),16 GB LPDDR...

# %%
data.to_csv('C:/mathan 2nd bca 2020-2023/WEB SCRAPPING PLIPKART MACBOOK PYTHON PROGRAM.CSV')
